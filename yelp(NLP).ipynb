# %%
import pandas as pd
import numpy as np
from gensim.models import FastText
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import string
import gensim.downloader as api

nltk.download('stopwords')
nltk.download('wordnet')

# Initialize WordNet lemmatizer and English stopwords
stemmer = WordNetLemmatizer()
en_stop = set(stopwords.words('english'))

# Read the Training Data
tips_df = pd.read_json('/content/drive/MyDrive/yelp/yelp_academic_dataset_tip.json', lines=True)
text_data = tips_df['text']

# Select a Subset of Words from the Training Data
subset_data = text_data.sample(n=1000)

# Preprocessing step
def preprocess_text(document):
    document = re.sub(r'\s+', ' ', document, flags=re.I) # Remove extra whitespaces
    document = re.sub(r'\W', ' ', str(document)) # Remove non-alphanumeric characters
    document = re.sub(r'\s+[a-zA-Z]\s+', ' ', document) # Remove single characters
    document = document.lower()
    tokens = document.split()
    tokens = [stemmer.lemmatize(word) for word in tokens]
    tokens = [word for word in tokens if word not in en_stop]
    tokens = [word for word in tokens if len(word) > 3]  # Filter out short words
    return tokens

# Preprocess the Text Data
corpus = [preprocess_text(text) for text in subset_data]

# function to Trains a FastText model on the given corpus
def train_fasttext_model(corpus, vector_size=100, window=5, min_count=1, workers=4):
    model = FastText(sentences=corpus, vector_size=vector_size, window=window, min_count=min_count, workers=workers)
    return model

# Train FastText Model
model = train_fasttext_model(corpus)

# Choose 20 Random Words from the Training Data
random_words = np.random.choice(np.concatenate(corpus), size=20, replace=False)

# Get Embeddings for Random Words
embeddings = [model.wv[word] for word in random_words if word in model.wv]

# function to Finds the nearest and farthest words to the embeddings in the trained FastText model
def get_nearest_and_farthest_words(model, embeddings, n=10):
    nearest_words = []
    farthest_words = []

    for embedding in embeddings:
        similarities = cosine_similarity([embedding], model.wv.vectors)
        nearest_indices = np.argsort(similarities[0])[-(n+1):-1]  # Exclude the word itself
        farthest_indices = np.argsort(similarities[0])[:n]

        nearest_words.append([model.wv.index_to_key[idx] for idx in nearest_indices])
        farthest_words.append([model.wv.index_to_key[idx] for idx in farthest_indices])

    return nearest_words, farthest_words

# Find Nearest and Farthest Words
nearest_words, farthest_words = get_nearest_and_farthest_words(model, embeddings)

# Load Pretrained FastText Model
pretrained_model = api.load('fasttext-wiki-news-subwords-300')

# function to Finds the most similar and dissimilar words to the random words in the pretrained FastText model.
def get_pretrained_nearest_and_farthest_words(pretrained_model, random_words, n=10):
    pretrained_nearest_words = []
    pretrained_farthest_words = []

    for word in random_words:
        if word in pretrained_model:  # Check if word is in vocabulary
            nearest = pretrained_model.most_similar(word, topn=n)
            farthest = pretrained_model.most_similar(negative=[word], topn=n)
            pretrained_nearest_words.append([w[0] for w in nearest])
            pretrained_farthest_words.append([w[0] for w in farthest])
        else:
            pretrained_nearest_words.append([])
            pretrained_farthest_words.append([])

    return pretrained_nearest_words, pretrained_farthest_words

# Get most similar and dissimilar words for each random word
pretrained_nearest_words, pretrained_farthest_words = get_pretrained_nearest_and_farthest_words(pretrained_model, random_words)

# Print the Results
for idx, word in enumerate(random_words):
    print(f"Random Word: {word}")
    print("Trained Model - Nearest Words:", nearest_words[idx])
    print("Trained Model - Farthest Words:", farthest_words[idx])
    print("Pretrained Model - Most Similar Words:", pretrained_nearest_words[idx])
    print("Pretrained Model - Most Dissimilar Words:", pretrained_farthest_words[idx])
    print("\n")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Random Word: scratch
# Trained Model - Nearest Words: ['tapping', 'staying', 'hopping', 'redding', 'waiting', 'passing', 'free', 'pudding', 'disgusting', 'blocking']
# Trained Model - Farthest Words: ['idaho', 'issue', 'zodiac', 'olga', 'http', 'ravs', '5llmmaa', '45pm', 'angus', 'wifi']
# Pretrained Model - Most Similar Words: ['scratching', 'scratched', 'scratcher', 'scratch.', 'scratches', 'scratchin', 'from-scratch', 'scratchiness', 'scratchers', 'scratch-free']
# Pretrained Model - Most Dissimilar Words: ['ಹೊಸ', 'قوی', 'تصل', 'சர', '၌', 'قرب', 'रष', 'हू', 'യത', 'கன']
#
#
# Random Word: said
# Trained Model - Nearest Words: ['anyone', 'bothered', 'skating', 'situation', 'eater', 'leftover', 'hairdresser', 'young', 'manager', 'salmon']
# Trained Model - Farthest Words: ['2013', 'iozzo', 'kabob', '2017', 'http', 'nudie', 'asset', 'text', 'html', '2018']
# Pretrained Model - Most Similar Words: ['says', 'told', '-said', 'said--and', 'said.One', 'remarked', 'noted', 'argued', 'said.But', 'wrote']
# Pretrained Model - Most Dissimilar Words: ['\uf0de', 'இரவு', 'டுமே', 'yS', 'h1H', 'ÂµÂ', 'অব', 'tÃ', '-Ã', 'ღღ']
#
#
# Random Word: love
# Trained Model - Nearest Words: ['considering', 'looking', 'bartending', 'making', 'blocking', 'frustrating', 'buying', 'building', 'lover', 'loved']
# Trained Model - Farthest Words: ['zodiac', 'ravs', 'ipads', 'html', 'idaho', 'ravioli', 'kibobs', '100320551', 'bistro', 'keep']
# Pretrained Model - Most Similar Words: ['love--and', 'loves', 'love--', 'hate', 'lover', 'loving', 'lovley', 'love-', '-love', 'loved']
# Pretrained Model - Most Dissimilar Words: ['ནས', 'དུ', 'དང', 'دهه', 'சர', 'परन', '၌', 'དེ', 'അന', 'ചില']
#
#
# Random Word: olive
# Trained Model - Nearest Words: ['wing', 'could', 'returning', 'river', 'pouring', 'drive', 'give', 'liver', 'predetermined', 'live']
# Trained Model - Farthest Words: ['ravs', 'html', '100th', 'zodiac', 'afghan', 'boochcraft', 'ummm', 'murica', 'mmnlnm0', '11am']
# Pretrained Model - Most Similar Words: ['olives', 'olive-oil', 'olive-branch', 'olive-tree', 'olive-colored', 'olive-coloured', 'olive-green', 'olive-brown', 'almond', 'olive-wood']
# Pretrained Model - Most Dissimilar Words: ['\x1b', 'যতীন', 'எமது', 'பில', 'சர', 'களது', 'நாம', 'নাটক', 'எனும', 'இதை']
#
#
# Random Word: attention
# Trained Model - Nearest Words: ['coming', 'letting', 'going', 'rating', 'topping', 'lagging', 'location', 'sharing', 'charging', 'convention']
# Trained Model - Farthest Words: ['http', 'zodiac', 'ravs', 'ipads', 'html', 'idaho', 'kabob', 'kafta', 'jamaica', 'kibobs']
# Pretrained Model - Most Similar Words: ['attentions', 'atttention', 'attention-', 'attention--', 'attention.', 'attention--and', 'Attention', 'attantion', 'attension', 'focus']
# Pretrained Model - Most Dissimilar Words: ['سم', 'سنه', 'h1H', 'मय', 'रष', 'tÃ', 'В.', 'यद', 'परन', 'এন']
#
#
# Random Word: home
# Trained Model - Nearest Words: ['pouring', 'seating', 'outstanding', 'serving', 'everything', 'ordering', 'refreshing', 'king', 'watching', 'playing']
# Trained Model - Farthest Words: ['zodiac', 'ipads', 'http', 'kayla', 'idaho', 'html', 'ravs', 'byob', 'ravioli', 'kibobs']
# Pretrained Model - Most Similar Words: ['house', 'homeplace', 'home-from-home', 'homes', 'home--and', 'stay-home', 'home-away-from-home', 'house-sit', 'mobile-home', 'home--a']
# Pretrained Model - Most Dissimilar Words: ['அவ', '∊', 'དུ', 'b,', 'ทั', 'യത', 'นี', 'കി', 'ာ', 'تصل']
#
#
# Random Word: perfect
# Trained Model - Nearest Words: ['passing', 'cover', 'liver', 'dressing', 'piping', 'relaxing', 'recommendation', 'recent', 'perfection', 'perfectly']
# Trained Model - Farthest Words: ['byob', 'zodiac', 'html', 'ipads', 'ravs', 'kabob', 'ravioli', '11am', 'http', 'scam']
# Pretrained Model - Most Similar Words: ['ideal', 'imperfect', 'perfection', 'near-perfect', 'flawless', 'unperfect', 'perfectible', 'perfect-', 'non-perfect', 'perfectly']
# Pretrained Model - Most Dissimilar Words: ['சர', 'তৎকালীন', 'অধিক', 'रष', '၌', 'परन', 'যন', 'യത', 'جبکہ', 'शकूर']
#
#
# Random Word: dirty
# Trained Model - Nearest Words: ['stopping', 'including', 'filling', 'dining', 'tipping', 'sophisticated', 'excellent', 'always', 'special', 'dirt']
# Trained Model - Farthest Words: ['zodiac', 'ahhhh', 'http', 'ipads', '5llmmaa', 'byob', 'nashy', 'html', 'blaze', 'jamaica']
# Pretrained Model - Most Similar Words: ['filthy', 'grubby', 'dirtier', 'dirtying', 'nasty', 'mucky', 'dirty-looking', 'stinky', 'dirties', 'dirtiest']
# Pretrained Model - Most Dissimilar Words: ['تضم', 'ಹೊಸ', 'परन', 'றுக', 'ಈಗ', 'তৎকালীন', 'हू', 'ளன', '၌', 'வகை']
#
#
# Random Word: international
# Trained Model - Nearest Words: ['making', 'topping', 'disappointing', 'everything', 'coming', 'leading', 'king', 'parking', 'sharing', 'working']
# Trained Model - Farthest Words: ['ravs', 'zodiac', 'http', 'idaho', '5llmmaa', 'kibobs', 'jamaica', 'ipads', 'apology', '2011']
# Pretrained Model - Most Similar Words: ['inter-national', 'national', 'internatinal', 'interational', 'internationally-based', 'international-level', 'interntional', 'inernational', 'global', 'internation']
# Pretrained Model - Most Dissimilar Words: ['വന', 'हू', 'ளன', 'ബ', 'இரவு', 'അന', 'ಈಗ', 'मय', 'കി', 'కడ']
#
#
# Random Word: hawaii
# Trained Model - Nearest Words: ['drive', 'quite', 'nutritional', 'sample', 'complained', 'casino', 'sooo', 'also', 'hoagy', 'hawaiian']
# Trained Model - Farthest Words: ['bisque', '45pm', 'tuna', 'tampa', 'bonus', 'frideeeeeeyyyy', 'murica', 'katie', 'sketch', '10pm']
# Pretrained Model - Most Similar Words: ['hawaiian', 'maui', 'honolulu', 'california', 'guam', 'alaska', 'Hawaii', 'bahamas', 'florida', 'taiwan']
# Pretrained Model - Most Dissimilar Words: ['गत', 'যতীন', 'নাটক', 'وینس', 'எனும', 'றுக', 'ⲛⲧⲉ', 'இவ', 'சுற', 'زنان']
#
#
# Random Word: bloody
# Trained Model - Nearest Words: ['served', 'tried', 'eating', 'chester', 'semester', 'trying', 'grouper', 'blocking', 'good', 'satisfying']
# Trained Model - Farthest Words: ['ravs', 'ahhhh', 'zodiac', '100320551', 'http', 'ipads', 'iozzo', 'energy', '2011', 'nudie']
# Pretrained Model - Most Similar Words: ['blood-soaked', 'gruesome', 'brutal', 'ghastly', 'bloody-handed', 'bloddy', 'bloodly', 'bloodless', 'blood-stained', 'horrible']
# Pretrained Model - Most Dissimilar Words: ['تضم', 'परन', '၌', 'হন', 'எனவே', 'माह', 'नें', 'அவ', 'کئی', 'تصل']
#
#
# Random Word: music
# Trained Model - Nearest Words: ['service', 'offering', 'situation', 'station', 'aggravating', 'rental', 'seating', 'must', 'perfection', 'musical']
# Trained Model - Farthest Words: ['http', 'kalamata', 'html', 'issue', '2013', '87th', 'soggy', 'zodiac', 'idaho', 'oops']
# Pretrained Model - Most Similar Words: ['musics', 'musical', 'music--', 'non-music', 'music-', 'music--and', '-music', 'world-music', 'music-driven', 'music-based']
# Pretrained Model - Most Dissimilar Words: ['போக', 'இதை', 'அவ', 'இவர', 'பில', 'சர', 'அதன', 'இங', 'இதன', 'டான']
#
#
# Random Word: coast
# Trained Model - Nearest Words: ['seating', 'meeting', 'looking', 'lightning', 'listening', 'getting', 'coming', 'spring', 'filling', 'eating']
# Trained Model - Farthest Words: ['zodiac', 'ravioli', 'ravs', 'ipads', 'kayla', 'jamaica', 'kabob', 'http', 'dark', 'idaho']
# Pretrained Model - Most Similar Words: ['coasts', 'coastline', 'coast-line', 'coast.', 'inland', 'sea-coast', 'coastland', 'midcoast', 'shore', 'coastal']
# Pretrained Model - Most Dissimilar Words: ['དང', 'དེ', 'ནས', 'དུ', 'ཞིག', 'शकूर', 'அவ', 'வம', 'அவை', 'ཡིན']
#
#
# Random Word: great
# Trained Model - Nearest Words: ['king', 'wing', 'amazing', 'taking', 'eating', 'letting', 'meeting', 'playing', 'working', 'making']
# Trained Model - Farthest Words: ['zodiac', 'ravs', 'ipads', 'kafta', 'jamaica', 'http', '45pm', 'html', 'ahhhh', 'ravioli']
# Pretrained Model - Most Similar Words: ['tremendous', 'terrific', 'wonderful', 'greate', 'greatest', 'incredible', 'huge', 'marvelous', 'fantastic', 'enormous']
# Pretrained Model - Most Dissimilar Words: ['रष', 'དུ', 'ာ', 'சர', 'യത', 'നത', 'போக', 'அவ', 'കി', 'கையை']
#
#
# Random Word: really
# Trained Model - Nearest Words: ['making', 'recycling', 'king', 'thing', 'spring', 'eating', 'effing', 'meeting', 'wing', 'ordering']
# Trained Model - Farthest Words: ['zodiac', 'http', 'ravioli', 'ipads', 'ravs', '2011', '2013', 'kibobs', 'kabob', 'idaho']
# Pretrained Model - Most Similar Words: ['actually', 'definitely', 'reallly', 'truly', 'realllly', 'obviously', 'hardly', 'actuallly', 'just', 'certainly']
# Pretrained Model - Most Dissimilar Words: ['यद', 'சர', 'रष', 'பாடல', '\uf0de', 'माह', 'യത', 'དུ', 'சுற', 'मों']
#
#
# Random Word: standard
# Trained Model - Nearest Words: ['setting', 'effing', 'everything', 'lover', 'ordering', 'playing', 'star', 'annoying', 'outstanding', 'stand']
# Trained Model - Farthest Words: ['ipads', 'ravs', 'html', 'ravioli', 'apology', 'zodiac', 'poca', 'murica', 'idaho', '100320551']
# Pretrained Model - Most Similar Words: ['standards', 'pre-standard', 'standard-', 'semi-standard', 'quasi-standard', 'world-standard', 'standards-', 'non-standard', 'professional-standard', 'standardized']
# Pretrained Model - Most Dissimilar Words: ['சர', 'हू', 'ബ', 'അന', 'ഗ', 'ങള', 'रष', 'കി', 'ധ', 'यद']
#
#
# Random Word: chargrilled
# Trained Model - Nearest Words: ['ordering', 'craving', 'waiting', 'changing', 'letting', 'welcoming', 'fried', 'staying', 'charging', 'grilled']
# Trained Model - Farthest Words: ['http', 'idaho', 'html', 'kibobs', '100320551', '45pm', 'kafta', '5llmmaa', '2013', 'zodiac']
# Pretrained Model - Most Similar Words: ['chargrill', 'char-grilled', 'Chargrilled', 'grilled', 'crisp-fried', 'flame-grilled', 'pan-fried', 'charcoal-grilled', 'barbecued', 'wood-grilled']
# Pretrained Model - Most Dissimilar Words: ['В.', 'शकूर', 'ღღ', 'அவை', 'போக', 'சர', 'இவர', 'றுக', 'எனும', 'परन']
#
#
# Random Word: ambience
# Trained Model - Nearest Words: ['everything', 'science', 'experienced', 'dressing', 'ambiance', 'making', 'lagging', 'saying', 'wing', 'experience']
# Trained Model - Farthest Words: ['zodiac', 'ipads', 'keto', '11am', 'http', 'kabob', '1990', 'value', 'text', 'ravs']
# Pretrained Model - Most Similar Words: ['ambiance', 'ambiences', 'ambient', 'vibe', 'spaciousness', 'atmosphere', 'atmospherics', 'soundscape', 'vibrance', 'decor']
# Pretrained Model - Most Dissimilar Words: ['போக', 'இதை', 'नें', 'இவர', 'கன', 'ധ', 'تضم', 'रष', 'అన', 'இங']
#
#
# Random Word: great
# Trained Model - Nearest Words: ['king', 'wing', 'amazing', 'taking', 'eating', 'letting', 'meeting', 'playing', 'working', 'making']
# Trained Model - Farthest Words: ['zodiac', 'ravs', 'ipads', 'kafta', 'jamaica', 'http', '45pm', 'html', 'ahhhh', 'ravioli']
# Pretrained Model - Most Similar Words: ['tremendous', 'terrific', 'wonderful', 'greate', 'greatest', 'incredible', 'huge', 'marvelous', 'fantastic', 'enormous']
# Pretrained Model - Most Dissimilar Words: ['रष', 'དུ', 'ာ', 'சர', 'യത', 'നത', 'போக', 'அவ', 'കി', 'கையை']
#
#
# Random Word: getting
# Trained Model - Nearest Words: ['king', 'making', 'everything', 'coming', 'outing', 'wing', 'bring', 'thing', 'letting', 'setting']
# Trained Model - Farthest Words: ['zodiac', 'http', 'ipads', 'idaho', 'ravs', 'kibobs', 'ravioli', 'ahhhh', '2011', 'kafta']
# Pretrained Model - Most Similar Words: ['gettting', 'geting', 'get', 'gettng', 'going', 'having', 'gotten', 'gettign', 'got', 'gettings']
# Pretrained Model - Most Dissimilar Words: ['tÃ', 'Го', 'रष', 'वं', 'mÃ', 'ಹೊಸ', 'அக', 'சர', 'सद', 'வண']
